# %% [markdown]
# <h1><span style="color:DodgerBlue;font-family:'Arial';">Serieclustring for HeCore</span></h1><br>
#
# Versjon: juni 2018

# %% [markdown]
# <div style="font-family:'Palatino Linotype';font-size:1.2em;">
#
# <h2><span style="color:gray;font-family:'Arial';">Om notebooken</span></h2><br>
#
# Første celle nedenfor er en javascript-celle som ved aktivering sørger for å skjule mesteparten av koden. For å se på koden er det bare å bytte ut tallet for 'height' med 'auto'.</div>

# %%
# %%javascript
# // Skjul koden i påfølgende celle
# // kode for å finne gjeldene celle er hentet fra bruker minrk på SO
# var cell_element = this.element.parents('.cell');
# var cell_idx = Jupyter.notebook.get_cell_elements().index(cell_element);
#
# $('.CodeMirror').eq(cell_idx+1).css('height', '70')
# $('.CodeMirror').eq(cell_idx+2).css('height', '70')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import json
import requests
from IPython.display import HTML
import seaborn as sns
from scipy.spatial.distance import cosine
import networkx as nx

sns.set_style('white')
# %matplotlib inline

# %%
def get_freq(urn, top=50, cutoff=3):
    r = requests.get("https://api.nb.no/ngram/urnfreq", json={'urn':urn, 'top':top, 'cutoff':cutoff})
    return Counter(dict(r.json()))

def get_urn(metadata):
    r = requests.get('https://api.nb.no/ngram/urn', json=metadata)
    return r.json()

def get_papers(top=5, cutoff=5, navn='%', yearfrom=1800, yearto=2020, samplesize=100):
    
    div = lambda x, y: (int(x/y), x % y)
    chunks = 20
    
    
    # split samplesize into chunks, go through the chunks and then the remainder
    
    (first, second) = div(samplesize, chunks)
    r = []
    
    # collect chunkwise 
    for i in range(first):
        r += requests.get("https://api.nb.no/ngram/avisfreq", json={'navn':navn, 'top':top, 'cutoff':cutoff,
                                                              'yearfrom':yearfrom, 'yearto':yearto,'samplesize':chunks}
                         ).json()
    
    
    # collect the remainder
    r += requests.get("https://api.nb.no/ngram/avisfreq", json={'navn':navn, 'top':top, 'cutoff':cutoff,
                                                              'yearfrom':yearfrom, 'yearto':yearto,'samplesize':second}
                         ).json()

    return [dict(x) for x in r]

def collocation(word, yearfrom=2010, yearto=2018, before=3, after=3, limit=1000, corpus='avis'):
    data =  requests.get(
        "https://api.nb.no/ngram/collocation", 
        params={
            'word':word,
            'corpus':corpus, 
            'yearfrom':yearfrom, 
            'before':before,
            'after':after,
            'limit':limit,
            'yearto':yearto}).json()
    return pd.DataFrame.from_dict(data['freq'], orient='index')

def heatmap(df, color='green'):
    return df.fillna(0).style.background_gradient(cmap=sns.light_palette(color, as_cmap=True))

def get_corpus_text(urns, top = 10000, cutoff=5):
    k = dict()
    for u in urns:
        #print(u)
        k[u] = get_freq(u, top = top, cutoff = cutoff)
    return pd.DataFrame(k)

def normalize_corpus_dataframe(df):
    colsums = df.sum()
    for x in colsums.index:
        #print(x)
        df[x] = df[x].fillna(0)/colsums[x]
    return True

def show_korpus(korpus, start=0, size=4, vstart=0, vsize=20, sortby = ''):
    """Show corpus as a panda dataframe
    start = 0 indicates which dokument to show first, dataframe is sorted according to this
    size = 4 how many documents (or columns) are shown
    top = 20 how many words (or rows) are shown"""
    if sortby != '':
        val = sortby
    else:
        val = korpus.columns[start]
    return korpus[korpus.columns[start:start+size]].sort_values(by=val, ascending=False)[vstart:vstart + vsize]

def aggregate(korpus):
    """Make an aggregated sum of all documents across the corpus, here we use average"""
    return pd.DataFrame(korpus.fillna(0).mean(axis=1))

def convert_list_of_freqs_to_dataframe(referanse):
    """The function get_papers() returns a list of frequencies - convert it"""
    res = []
    for x in referanse:
        res.append( dict(x))
    result = pd.DataFrame(res).transpose()
    normalize_corpus_dataframe(result)
    return result

def get_corpus(top=5, cutoff=5, navn='%', corpus='avis', yearfrom=1800, yearto=2020, samplesize=10):
    if corpus == 'avis':
        result = get_papers(top=top, cutoff=cutoff, navn=navn, yearfrom=yearfrom, yearto=yearto, samplesize=samplesize)
        res = convert_list_of_freqs_to_dataframe(result)
    else:
        urns = get_urn({'author':navn, 'year':yearfrom, 'neste':yearto-yearfrom, 'limit':samplesize})
        res = get_corpus_text([x[0] for x in urns], top=top, cutoff=cutoff)
    return res


def make_a_collocation(word, period=(1990, 2000),before=5, after=5,corpus='avis', samplesize=100, limit=2000):
    collocates = collocation(word, yearfrom=period[0], yearto = period[1], before=before, after=after,
                            corpus=corpus, limit=limit)
    collocates.columns = [word]
    reference = get_corpus(yearfrom=period[0], yearto=period[1], samplesize=samplesize)
    ref_agg = aggregate(reference)
    ref_agg.columns = ['reference_corpus']
    return  ref_agg



def compute_assoc(coll_frame, column, exponent=1.1, refcolumn = 'reference_corpus'):
    return pd.DataFrame(coll_frame[column]**exponent/coll_frame.mean(axis=1))
    

class Cluster:
    from IPython.display import HTML, display
    import pandas as pd
    import json
    
    def __init__(self, word = '', filename = '', period = (1950,1960) , before = 5, after = 5, corpus='avis', reference = 200, 
                 word_samples=1000):
        import pandas
        
        if word != '':
            self.collocates = collocation(word, yearfrom=period[0], yearto = period[1], before=before, after=after,
                                corpus=corpus, limit=word_samples)
            #print(self.collocates[:10])
            self.collocates.columns = [word]
            if type(reference) is pandas.core.frame.DataFrame:
                reference = reference
            elif type(reference) is int:
                reference = get_corpus(yearfrom=period[0], yearto=period[1], corpus=corpus, samplesize=reference)
            else:
                reference = get_corpus(yearfrom=period[0], yearto=period[1], corpus=corpus, samplesize=int(reference))

            self.reference = aggregate(reference)
            self.reference.columns = ['reference_corpus']        
            self.word = word
            self.period = period
            self.corpus = corpus
        else:
            if filename != '':
                self.load(filename)
            
                
    def cluster_set(self, exponent=1.1, top = 200, aslist=True):
        combo_corp = self.reference.join(self.collocates, how='outer')
        normalize_corpus_dataframe(combo_corp)
        korpus = compute_assoc(combo_corp, self.word, exponent)
        korpus.columns = [self.word]
        res = korpus.sort_values(by=self.word, ascending=False).iloc[:top]
        if aslist == True:
            res = HTML(', '.join(list(res.index)))
        return res
    
    def add_reference(self, number=20):
        ref = get_corpus(yearfrom=self.period[0], yearto=self.period[1], samplesize=number)
        ref = aggregate(ref)
        ref.columns = ['add_ref']
        normalize_corpus_dataframe(ref)
        self.reference = aggregate(self.reference.join(ref, how='outer'))
        return True
    
    def save(self, filename=''):
        if filename == '':
            filename = "{w}_{p}-{q}.json".format(w=self.word,p=self.period[0], q = self.period[1])
        model = {
            'word':self.word,
            'period':self.period,
            'reference':self.reference.to_dict(),
            'collocates':self.collocates.to_dict(),
            'corpus':self.corpus
        }
        with open(filename, 'w', encoding = 'utf-8') as outfile:
            print('lagrer til:', filename)
            outfile.write(json.dumps(model))
        return True

    def load(self, filename):
        with open(filename, 'r') as infile:
            try:
                model = json.loads(infile.read())
                #print(model['word'])
                self.word = model['word']
                self.period = model['period']
                self.corpus = model['corpus']
                self.reference = pd.DataFrame(model['reference'])
                self.collocates = pd.DataFrame(model['collocates'])
            except:
                print('noe gikk galt')
        return True
    
    def search_words(self, words, exponent=1.1):
        if type(words) is str:
            words = [w.strip() for w in words.split()]
        sub = [w for w in words if w in self.cluster_set(exponent=exponent, top=0, aslist=False).index]
        return self.cluster_set(exponent=exponent, top=0, aslist=False).transpose()[sub].transpose().sort_values(by=self.word, ascending=False)
            
        

            
def make_newspaper_network(key, wordbag, titel='%', yearfrom='1980', yearto='1990', limit=500):
    import networkx as nx
    if type(wordbag) is str:
        wordbag = wordbag.split()
    r = requests.post("https://api.nb.no/ngram/avisgraph", json={
        'key':key, 
        'words':wordbag,
        'yearto':yearto,
    'yearfrom':yearfrom,
    'limit':limit})
    G = nx.Graph()
    if r.status_code == 200:
        G.add_weighted_edges_from([(x,y,z) for (x,y,z) in r.json() if z > 0 and x != y])
    else:
        print(r.text)
    return G

def make_network(urn, wordbag, cutoff=0):
    if type(urn) is list:
        urn = urn[0]
    if type(wordbag) is str:
        wordbag = wordbag.split()
    G = make_network_graph(urn, wordbag, cutoff)
    return G

def make_network_graph(urn, wordbag, cutoff=0):
    import networkx as nx
    
    r = requests.post("https://api.nb.no/ngram/graph", json={'urn':urn, 'words':wordbag})
    G = nx.Graph()
    G.add_weighted_edges_from([(x,y,z) for (x,y,z) in r.json() if z > cutoff and x != y])
    return G

def draw_graph_centrality(G, h=15, v=10, fontsize=20, k=0.2, arrows=False, font_color='black', threshold=0.01): 
    from pylab import rcParams
    import matplotlib.pyplot as plt
    
    node_dict = nx.degree_centrality(G)
    subnodes = dict({x:node_dict[x] for x in node_dict if node_dict[x] >= threshold})
    x, y = rcParams['figure.figsize']
    rcParams['figure.figsize'] = h, v
    pos =nx.spring_layout(G, k=k)
    ax = plt.subplot()
    ax.set_xticks([])
    ax.set_yticks([])
    G = G.subgraph(subnodes)
    nx.draw_networkx_labels(G, pos, font_size=fontsize, font_color=font_color)
    nx.draw_networkx_nodes(G, pos, alpha=0.5, nodelist=subnodes.keys(), node_size=[v * 1000 for v in subnodes.values()])
    nx.draw_networkx_edges(G, pos, alpha=0.7, arrows=arrows, edge_color='lightblue', width=1)

    rcParams['figure.figsize'] = x, y
    return True

def combine(clusters):
    """Make new collocation analyses from data in clusters"""
    colls = []
    collocates = clusters[0].collocates
    for c in clusters[1:]:
        collocates = collocates.join(c.collocates, rsuffix='-' + str(c.period[0]))
    return collocates

def cluster_join(cluster):
    clusters = [cluster[i] for i in cluster]
    clst = clusters[0].cluster_set(aslist=False)
    for c in clusters[1:]:
        clst = clst.join(c.cluster_set(aslist=False), rsuffix = '_'+str(c.period[0]))
    return clst

def serie_cluster(word, startår, sluttår, inkrement, before=5, after=5, reference=150, word_samples=500):
    tidscluster = dict()
    for i in range(startår, sluttår, inkrement):
        print(i)
        tidscluster[i] = Cluster(
            word, 
            corpus='avis', 
            period=(i, i + inkrement - 1), 
            before=after, 
            after=after, 
            reference=reference, 
            word_samples=word_samples)
        print(i, i+inkrement - 1)
    return tidscluster

def save_serie_cluster(tidscluster):
    for i in tidscluster:
        tidscluster[i].save()
    return 'OK'

def les_serie_cluster(word, startår, sluttår, inkrement):
    tcluster = dict()
    for i in range(startår, sluttår, inkrement):
        print(i, i+inkrement - 1)
        tcluster[i] = Cluster(filename='{w}_{f}-{t}.json'.format(w=word, f=i,t=i+inkrement - 1))
    return tcluster

# %% [markdown]
# <h2> <span style='color:tomato; font-family:"Arial"'>Lag kollokasjoner for tidsperioder og nettverk for ord</span></h2><br>

# %% [markdown]
# <div style="font-family:'Palatino Linotype';font-size:1.2em">
#
# Definer en serie cluster over en tidsperiode. Clusteret bygges med kommandoen **serie_cluster()** som i tillegg til Cluster-kommandoen tar parametrene startår, sluttår og årsinkrementet. Sjekk opp eksemplet under. Kommandoen skriver ut periodene etterhvert som de blir klare.
#
# </div>

# %%
tidscluster = serie_cluster(
    'AIDS', 
    1980, 
    2010, 
    10,
    before=4, 
    after=4, 
    reference=150, 
    word_samples=200)
# Out:
# 1980
# 1980 1989
# 1990
# 1990 1999
# 2000
# 2000 2009

# %% [markdown]
# <h2> <span style='color:tomato; font-family:"Arial"'>Heatmap</span></h2><br>

# %% [markdown]
# <div style="font-family:'Palatino Linotype';font-size:1.2em">
# Heatmap er på plass. Fyll inn navnet på et seriecluster i uttrykket under - neste versjon vil bli litt mer brukervennlig, men tror det her skal fungere.
#
# Antall rader endres i den siste hakeparentesen. Sorter på en kolonne ved å fyll inn kolonnenavnet der teksten er rød i cellen. Første kolonne har ikke fått årstall - det gjør den grei å starte med, siden første årstall kan variere.

# %%
heatmap(
    cluster_join(tidscluster).sort_values(by='AIDS', ascending=False)[:20]
)
# Out:
# <style  type="text/css" >
#     #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col0 {
#             background-color:  #008000;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col1 {
#             background-color:  #2b982b;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col2 {
#             background-color:  #47a747;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col0 {
#             background-color:  #2d992d;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col1 {
#             background-color:  #148b14;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col2 {
#             background-color:  #209220;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col0 {
#             background-color:  #6bbb6b;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col1 {
#             background-color:  #3ba13b;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col2 {
#             background-color:  #44a644;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow3_col0 {
#             background-color:  #74c074;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow3_col1 {
#             background-color:  #008000;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow3_col2 {
#             background-color:  #008000;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow4_col0 {
#             background-color:  #7fc67f;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow4_col1 {
#             background-color:  #359d35;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow4_col2 {
#             background-color:  #5cb35c;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow5_col0 {
#             background-color:  #9ed89e;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow5_col1 {
#             background-color:  #3fa33f;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow5_col2 {
#             background-color:  #4aa94a;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow6_col0 {
#             background-color:  #a0d9a0;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow6_col1 {
#             background-color:  #2b982b;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow6_col2 {
#             background-color:  #2a972a;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow7_col0 {
#             background-color:  #b8e6b8;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow8_col0 {
#             background-color:  #bde9bd;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow8_col1 {
#             background-color:  #339c33;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow9_col0 {
#             background-color:  #bee9be;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow9_col1 {
#             background-color:  #188d18;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow9_col2 {
#             background-color:  #329c32;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow10_col0 {
#             background-color:  #c0eac0;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow10_col1 {
#             background-color:  #41a441;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow11_col0 {
#             background-color:  #c7eec7;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow11_col1 {
#             background-color:  #47a747;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow11_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow12_col0 {
#             background-color:  #caf0ca;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow12_col1 {
#             background-color:  #43a543;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow12_col2 {
#             background-color:  #5ab25a;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow13_col0 {
#             background-color:  #cdf2cd;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow13_col1 {
#             background-color:  #4daa4d;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow13_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow14_col0 {
#             background-color:  #cff3cf;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow14_col1 {
#             background-color:  #188d18;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow14_col2 {
#             background-color:  #47a747;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow15_col0 {
#             background-color:  #d0f3d0;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow15_col1 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow15_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow16_col0 {
#             background-color:  #d1f4d1;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow16_col1 {
#             background-color:  #3fa33f;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow16_col2 {
#             background-color:  #4caa4c;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow17_col0 {
#             background-color:  #d9f8d9;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow17_col1 {
#             background-color:  #319b31;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow17_col2 {
#             background-color:  #369e36;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow18_col0 {
#             background-color:  #ddfbdd;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow18_col1 {
#             background-color:  #48a848;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow18_col2 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow19_col0 {
#             background-color:  #e5ffe5;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow19_col1 {
#             background-color:  #47a747;
#         }    #T_297d0426_a5b2_11e8_899d_d46d6d080fecrow19_col2 {
#             background-color:  #4fac4f;
#         }</style>
# <table id="T_297d0426_a5b2_11e8_899d_d46d6d080fec" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AIDS</th>
#         <th class="col_heading level0 col1" >AIDS_1990</th>
#         <th class="col_heading level0 col2" >AIDS_2000</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_297d0426_a5b2_11e8_899d_d46d6d080feclevel0_row0" class="row_heading level0 row0" >sykdommen</th>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col0" class="data row0 col0" >1.25299</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col1" class="data row0 col1" >1.06664</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow0_col2" class="data row0 col2" >1.00049</td>
#     </tr>    <tr>
#         <th id="T_297d0426_a5b2_11e8_899d_d46d6d080feclevel0_row1" class="row_heading level0 row1" >mot</th>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col0" class="data row1 col0" >1.2018</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col1" class="data row1 col1" >1.19729</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow1_col2" class="data row1 col2" >1.24062</td>
#     </tr>    <tr>
#         <th id="T_297d0426_a5b2_11e8_899d_d46d6d080feclevel0_row2" class="row_heading level0 row2" >smittet</th>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col0" class="data row2 col0" >1.13145</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col1" class="data row2 col1" >0.974137</td>
#         <td id="T_297d0426_a5b2_11e8_899d_d46d6d080fecrow2_col2" class="data row2 col2" >1.01703</td>
#     </tr>    <tr>
#         <th id="T_297d0426_a5b2_11e8_899d_d

# %% [markdown]
# <h2> <span style='color:tomato; font-family:"Arial"'>Inspeksjon</span></h2><br>

# %% [markdown]
# <div style="font-family:'Palatino Linotype';font-size:1.2em">
# Hvert cluster refereres til med startåret - her fra 1920 og oppover. Hvert år fungerer som et vanlig enkeltstående cluster

# %%
tidscluster[1980].cluster_set(exponent=1.1, top=150)
# Out:
# sykdommen, mot, smittet, HIV, tilfeller, AIDS, kampen, fryktede, om, døde, informasjon, Sykdommen, vaksine, tiltak, utviklet, blod, sykdom, rammet, dødelige, homofile, sykdommer, viruset, Afrika, bekjempe, registrert, programmer, bryter, HIV-smitte, spredning, sex, frykten, virus, kroppens, smitte, rammer, sprer, påvist, frykt, smitter, Om, overføres, spørsmål, pasienter, alvorlig, utvikle, hindre, ansikt, forårsaker, Magasinet, Frykten, stoffmisbruk, av, herpes, spredningen, sjukdommen, handlingsplan, utvikler, 20.05, homoseksuelle, hepatitt, Svarer, spre, kreft, narkotikamisbruk, smittsom, utbredelsen, oppdaget, herunder, syke, dødelig, Sosialkanalen, Hudson, diagnosen, trussel, Dagsrevyen, narkomane, skyldes, dør, frykter, død, symptomer, forebyggende, alla, MOT, Astor, OM, overlege, Ungdom, angår, rammes, faren, tilfelle, virussykdom, forebygge, pasient, overførbare, lider, opplysning, narkomani, Sten-Rune, smitta, bekjempelsen, bekjempelse, dr., homofili, krevd, via, dø, dommen, årsaken, Ansikt, konstatert, angar, smittsomme, utbredt, syk, blodoverføring, Rock, informere, livsfarlige, middel, mystiske, Helseråd, smittes, prostituerte, seksuell, hysteri, registrerte, tanke, tiltakene, fått, narkotika, Stockholm, Svenska, Immune, kjønnssykdom, ervervet, Ungdomskulturkampanjen, sprøytenarkomane, arbeidsplassen, 20.55, tiltaksplan, 21.45, immunsviktsykdommen, Sterner, blødere, behandling, opplysningene, NTB-Reuter, behandle

# %%
tidscluster[1990].cluster_set(exponent=1.1, top=150)
# Out:
# HIV, mot, utviklet, døde, Landsforeningen, KONTOR, sykdommen, kampen, HELSERÅDETS, rammet, dø, om, dør, kreft, Afrika, sex, tilfeller, MOT, Andrew, utvikle, av, Ungdom, sykdommer, smittet, utvikler, dødd, Tema, sparken, diagnosen, 09.25, AIDS, Special, sykdom, Awareness, forstår, Sex, diskusjon, Privatsak, Day, HIV-test, Alternative, informasjon, spredning, tema, spredningen, Degrassi, utviklingen, vaksine, temaet, tuberkulose, HIV-smitte, Advokat, syke, SOS, sprer, amerikanere, narkotika, medisin, pasienter, innvandrere, Romania, handler, Stand, Spørsmål, rammer, mennesker, bekjempe, Dokumentarfilm, TOM, frykten, By, No, HIV-positive, LMA, kjønnssykdommer, HIV-viruset, HELSERADETS, faren, homofile, Do, Dimensions, Sykdommen, pike, HANKS, Extra, dødelig, spre, smitte, dødelige, 22.50, What, personer, leben, utbredelsen, kur, finsk, Diskussion, Foundation, smittede, UK, omkring, Kampen, Mercury, 122, forebyggende, im, seksuelt, bekjempelsen, Begegnungen, Auslandsjournal, truer, hotet, homofili, Let, Benefit, viruset, sommerbesøk, forskning, død, Bild, tiltak, Haring, generell, døende, kampanjer, bakspejlet, Keith, Aars, Uganda, afrikanere, homoseksualitet, branner, overførbare, 21.55, afrikanske, nordmenn, Me, Helsedirektoratet, alvorlige, Studio, opplysning, Now, utbredt, verdenskongressen, Countrymusik, Landsforeninga, samles, HIV-TEST, Hanks, dreper

# %%
tidscluster[2000].cluster_set()
# Out:
# HIV, mot, kampen, of, Valley, døde, hiv, /, Afrika, rammet, malaria, dør, tuberkulose, kreft, End, bekjempe, Day, World, Staying, fattigdom, sykdommer, Alive, Concert, smittet, The, av, bekjempelse, sykdommen, utviklet, MOT, arbeid, kanten, plutselig, dø, fokus, lever, viktige, AIDS, Hanks, saksdokumenter, venn, sykdom, greier, sult, Landsforeningen, foreldrene, spredningen, prosjekt, undervise, UN, fiende, Bekjemp, kunnskap, epidemien, utvikler, homofile, linje, Forum, Sør-Afrika, verste, CNN, 2002, ofrer, Discovermagasinet, kriminalitet, with, 1991, Pluss, Arbeid, mennesker, Nelson, sørlige, Sosialt, Out, landets, arbeidsledighet, lider, behandling, Global, hepatitt, dødd, problematikken, spredning, 20.05, Africa, Verdens, gammel, krig, Against, HTV, haien, foreldreløse, FNs, grunn, on, Kampen, 01.45, Sammen, Assassins, epidemi, Make, Living, hardest, dødelig, spre, viruset, 1983, rollene, medisiner, Tom, pasienter, 10.05, Foundation, aids, Hiv, History, afrikanske, global, gatebarn, utgjør, Presents, medisin, Hope, syke, 11.50, utvikle, foreldre, mistet, Mark, problem, Heartbreak, UNICEF, Mandelas, Zimbabwe, diabetes, Damage, 03.35, Malaria, homofili, forebyggende, inntekt, OG, befolkningen, overgrep, vaksine, uoffisielt, Mercury, Wolf, Musik, DAY, KICKING, dreper, sprer, WORLD, dødsfall, osteoporose, forårsaker, arbeidet, FN, versjon, 02.35, 16.50, problemet, Kirkens, sønn, omkring, tilfeller, On, 15.15, 05.30, oppgradert, Mandela, levealder, pga, Ethiopia, pådro, Broken, generalsekretær, Specialist, overdrevne, Social, Nødhjelp, ramma, kampanje, HI, bekjempelsen, Gracie, berørt, Elton, Møt, Pornographers, WHO, og, åpenhet, homofil, seminar, million, mm., Top, News
